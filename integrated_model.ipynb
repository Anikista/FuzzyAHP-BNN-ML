# %%
from sklearn.svm import SVC
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns

# %%
raw_data=pd.read_excel("Final.xlsx")
raw_data.head(5)
# Out:
#             EWO No  Responsiveness  Co_operativeness  Transportation Quality  \
# 0  22 19 01 000001               5                 4                       3
# 1  22 19 01 000001               5                 4                       3
# 2  22 19 01 000002               3                 1                       3
# 3  22 19 01 000002               3                 1                       3
# 4  22 19 01 000002               3                 1                       3
#
#    Packaging  Order Date  Consistency  Item Name  On time Delivery  \
# 0          3       43461            4  Jute Yarn                 1
# 1          3       43461            4  Jute Yarn                 1
# 2          3       43466            4  Jute Yarn                 1
# 3          3       43466            4  Jute Yarn                 1
# 4          3       43466            4  Jute Yarn                 1
#
#    Delivery Performance  ...  Quality  Order Value  Delivery  Reliability  \
# ...

# %%
x = raw_data['Vendor']
y = raw_data['Length(cm)']


# Create a scatter plot
plt.scatter(x, y)

# Add labels and title
plt.xlabel('Vendor')
plt.ylabel('Length')
plt.title('Vendor Comparison')
plt.figure(figsize=(50, 60))
# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
outliers=[]
def detect_outlier(data_1):
    outliers=[]
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
value = set(raw_data['Vendor'])
for i in value:
    print(i)
    raw_dataa=raw_data[raw_data['Vendor'] == i]
    dataset=raw_dataa['Length(cm)']
    outlier_datapoints = detect_outlier(dataset)
    for j in outlier_datapoints:
        filtered_data = raw_data[(raw_data['Vendor'] == i) & (raw_data['Length(cm)'] == j)]
        raw_data.drop(filtered_data.index, inplace=True)
# Out:
# V56
# V23
# V25
# V65
# V14
# V28
# V32
# V93
# V63
# V106
# V35
# V104
# V95
# V71
# V125
# V81
# V58
# V55
# V09
# V47
# V39
# V60
# V110
# V94
# V88
# V53
# V11
# V33
# V68
# V46
# V42
# V31
# V40
# V08
# V29
# V03
# V62
# V16
# V80
# C:\Users\User\AppData\Local\Temp\ipykernel_6680\1648123273.py:12: RuntimeWarning: invalid value encountered in scalar divide
#   z_score= (y - mean_1)/std_1
# V37
# V12
# V121
# V79
# V54
# V119
# V91
# V82
# V24
# V66
# V89
# V64
# V15
# V126
# V122
# V99
# V101
# V92
# V02
# V77
# V38
# V13
# V05
# V01
# V10
# V69
# V107
# V76
# V86
# V21
# V34
# V20
# V118
# V51
# V41
# V61
# V98
# V96
# V74
# V123
# V07
# V50
# V19
# V06
# V85
# V128
# V48
# V103
# V22
# V100
# V105
# V117
# V17
# V30
# V127
# V90
# V120
# V36
# V109
# V84
# V49
# V52
# V108
# V26
# V87
# V124
# V45
# V73
# V78
# V97
# V57
# V75
# V27
# V18
# V70
# V43
# V83
# V04
# V72
# V67
# V102
# V44
# V59

# %%
a = raw_data['Vendor']
b = raw_data['Length(cm)']
# colors = numeric_form_vendor

# Create a scatter plot
plt.scatter(a, b)

# Add labels and title
plt.xlabel('Vendor')
plt.ylabel('Length')
plt.title('Vendor Comparison')
plt.figure(figsize=(50, 60))
# Show the plot
plt.show()

# %%
x = raw_data['Vendor']
y = raw_data['Strength (gm/denier)']


# Create a scatter plot
plt.scatter(x, y)

# Add labels and title
plt.xlabel('Vendor')
plt.ylabel('Strength (gm/denier)')
plt.title('Vendor Comparison')
plt.figure(figsize=(50, 60))
# Show the plot
plt.show()

# %%
for i in value:

    raw_dataa=raw_data[raw_data['Vendor'] == i]
    dataset=raw_dataa['Strength (gm/denier)']
    outlier_datapoints = detect_outlier(dataset)
    for j in outlier_datapoints:
        filtered_data = raw_data[(raw_data['Vendor'] == i) & (raw_data['Strength (gm/denier)'] == j)]
        raw_data.drop(filtered_data.index, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6680\1648123273.py:12: RuntimeWarning: invalid value encountered in scalar divide
#   z_score= (y - mean_1)/std_1

# %%
a = raw_data['Vendor']
b = raw_data['Strength (gm/denier)']
# colors = numeric_form_vendor

# Create a scatter plot
plt.scatter(a, b)

# Add labels and title
plt.xlabel('Vendor')
plt.ylabel('Strength (gm/denier)')
plt.title('Vendor Comparison')
plt.figure(figsize=(50, 60))
# Show the plot
plt.show()

# %%
x = raw_data['Vendor']
y = raw_data['Unit price']


# Create a scatter plot
plt.scatter(x, y)

# Add labels and title
plt.xlabel('Vendor')
plt.ylabel('Unit price')
plt.title('Vendor Comparison')
plt.figure(figsize=(50, 60))
# Show the plot
plt.show()

# %%
for i in value:

    raw_dataa=raw_data[raw_data['Vendor'] == i]
    dataset=raw_dataa['Unit price']
    outlier_datapoints = detect_outlier(dataset)
    for j in outlier_datapoints:
        filtered_data = raw_data[(raw_data['Vendor'] == i) & (raw_data['Unit price'] == j)]
        raw_data.drop(filtered_data.index, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6680\1648123273.py:12: RuntimeWarning: invalid value encountered in scalar divide
#   z_score= (y - mean_1)/std_1

# %%
a = raw_data['Vendor']
b = raw_data['Unit price']


# Create a scatter plot
plt.scatter(a, b)

# Add labels and title
plt.xlabel('Vendor')
plt.ylabel('Unit price')
plt.title('Vendor Comparison')
plt.figure(figsize=(50, 60))
# Show the plot
plt.show()

# %%
precise_data1 = raw_data.drop(raw_data[raw_data['Total Price'] == 0].index)
heatmap_data=precise_data1.drop(['EWO No','Order Date','Item Name','Delivery Date','Supplier Address'],1)
precise_data=precise_data1.drop(['EWO No','Order Date','Item Name','Delivery Date','Supplier Address','Vendor'],1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6680\3824315637.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   heatmap_data=precise_data1.drop(['EWO No','Order Date','Item Name','Delivery Date','Supplier Address'],1)
# C:\Users\User\AppData\Local\Temp\ipykernel_6680\3824315637.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   precise_data=precise_data1.drop(['EWO No','Order Date','Item Name','Delivery Date','Supplier Address','Vendor'],1)

# %%
targets=heatmap_data['Vendor']
x_train,x_test,y_train,y_test=train_test_split(precise_data,targets,test_size=0.20,random_state=100)
print(len(x_train))
print(len(x_test))
# Out:
# 6163
# 1541

# %%
x_train = x_train.apply(pd.to_numeric, errors='coerce').fillna(0)
x_test = x_test.apply(pd.to_numeric, errors='coerce').fillna(0)

# %%
x_train.head(5)
# Out:
#       Responsiveness  Co_operativeness  Transportation Quality  Packaging  \
# 3221               5                 4                       3          3
# 4415               4                 3                       3          3
# 1249               5                 4                       3          3
# 2701               5                 4                       3          3
# 2554               3                 1                       3          3
#
#       Consistency  On time Delivery  Delivery Performance  Fineness  \
# 3221            4                 1                     4         5
# 4415            4                 1                     3         5
# 1249            4                 1                     1         5
# 2701            4                 1                     4         5
# 2554            4                 1                     5         5
#
#       Length(cm)  Strength (gm/denier)  ...   Quality  Order Value  Delivery  \
# ...

# %%
rf= RandomForestClassifier(n_estimators=500, random_state=42)
rf.fit(x_train,y_train)
rf.score(x_test,y_test)
# Out:
# 0.9409474367293965

# %%
import math
res=int(input("Enter the value of responsivenes[1~5]"))
coop=int(input("Enter the value of Cooperativeness[1~5]"))
trans=int(input("Enter the value of Transportation Quality[1~5]"))
pack=int(input("Enter the value of packaging[1~5]"))
con=int(input("Enter the value of consistency[1~5]"))
ont=int(input("Enter the value of on time delivery[0/1]"))
dlp=int(input("Enter the value of delivery performance[1~5]"))
fin=int(input("Enter the value of Fineness[1~5]"))
leng=float(input("Enter the value of yarn length in cm"))
strn=float(input("Enter the value of yarn strength in gm/denier"))
flex=int(input("Enter the value of Flexibility[1~5]"))
odf=int(input("Enter the value of order fullfillment[0/1]"))
afs=int(input("Enter the value of after sale service[1~5]"))
qnt=int(input("Enter the value of quantity"))
unt=float(input("Enter the value of unit price"))
ltd=int(input("Enter the value of lead time[1~5]"))
tp=unt*qnt

precise_data=raw_data
file_path = "main_data.xlsx"
sheet_name = "Sheet2"

# Read the data from the Excel file into a Pandas DataFrame
weighted_value = pd.read_excel(file_path, sheet_name=sheet_name)

# testt=precise_data[0:25]
# for index, row in testt.iterrows():
#     print(index)
weighted_length=(((leng-min(precise_data['Length(cm)']))*5)/(max(precise_data['Length(cm)']-min(precise_data['Length(cm)']))))
weighted_length=math.ceil(weighted_length)

weighted_strength=(((strn-min(precise_data['Strength (gm/denier)']))*5)/(max(precise_data['Strength (gm/denier)']-min(precise_data['Strength (gm/denier)']))))
weighted_strength=math.ceil(weighted_strength)

weighted_qnt=(((qnt-min(precise_data['Total Qty in (Kg)'])-0.1)*5)/(max(precise_data['Total Qty in (Kg)']-min(precise_data['Total Qty in (Kg)']))))
weighted_qnt=math.ceil(weighted_qnt)

weighted_T_price=(((tp-min(precise_data['Total Price'])-0.1)*5)/(max(precise_data['Total Price']-min(precise_data['Total Price']))))
weighted_T_price=5-math.ceil(weighted_T_price)

weighted_U_price=(((unt-min(precise_data['Unit price'])-0.1)*5)/(max(precise_data['Unit price']-min(precise_data['Unit price']))))
weighted_U_price=5-math.ceil(weighted_U_price)

weighted_lead=(((ltd-min(precise_data['Lead Time'])-0.1)*5)/(max(precise_data['Lead Time']-min(precise_data['Lead Time']))))
weighted_lead=(5-math.ceil(weighted_lead))*0.1650
# print(weighted_lead)
Quality=(fin*weighted_value['Individual weighting'][0]+weighted_length*weighted_value['Individual weighting'][1]+weighted_strength*weighted_value['Individual weighting'][2]+pack*weighted_value['Individual weighting'][3])
order_value=weighted_qnt*weighted_value['Individual weighting'][4]+weighted_T_price*weighted_value['Individual weighting'][5]+weighted_U_price*weighted_value['Individual weighting'][6]
delivery=ont*5*weighted_value['Individual weighting'][8]+dlp*weighted_value['Individual weighting'][9]+con*weighted_value['Individual weighting'][10]+odf*5*weighted_value['Individual weighting'][11]
reliability=res*weighted_value['Individual weighting'][12]+coop*weighted_value['Individual weighting'][13]+flex*weighted_value['Individual weighting'][14]+afs*weighted_value['Individual weighting'][15]
ttl_p=((weighted_lead+Quality+order_value+delivery+reliability)/5)*100


unc_resp=(5-res)/5
unc_Co=(5-coop)/5
unc_trans=(5-trans)/5
unc_pack=(5-pack)/5
unc_conc=(5-con)/5
unc_ont=(5-ont*5)/5
unc_dlp=(5-dlp)/5
unc_fin=(5-fin)/5
unc_len=(355-leng)/355
unc_stren=(7-strn)/7
unc_flex=(5-flex)/5
unc_orfl=(1-odf)/1
unc_afss=(5-afs)/5
unc_tqik=(1000-qnt)/1000
unc_tp=(tp)/3365
unc_lt=(ltd)/25
unc_up=(unt)/17

df=pd.ExcelFile("uncertainty.xlsx")
df1 = pd.read_excel(df, 'Main_Factor')
df2 = pd.read_excel(df, 'Operational_risk_probability')
df3= pd.read_excel(df, 'Network_risk_probability')
df4=pd.read_excel(df, 'External_risk_probability')



orp=0
for i in range(len(df2)):
    if df2.Fineness[i]==1:
        p_a= unc_fin
    else:
        p_a=1-unc_fin
    if df2.Length[i]==1:
        p_b=unc_len
    else:
        p_b=1-unc_len
    if df2.Strength[i]==1:
        p_c=unc_stren
    else:
        p_c=1-unc_stren
    if df2['Unit Price'][i]==1:
        p_d=unc_up
    else:
        p_d=1-unc_up
    if df2['Total Quantity'][i]==1:
        p_e=unc_tp
    else:
        p_e=1-unc_tp
    if df2['Packaging'][i]==1:
        p_f=unc_pack
    else:
        p_f=1-unc_pack
    orp=orp+df2['Operational risk'][i]*p_a*p_b*p_c*p_d*p_e*p_f

nrp=0
for i in range(len(df3)):
    if df3['Lead Time'][i]==1:
        p_a= unc_lt
    else:
        p_a=1-unc_lt
    if df3['Order Fullfillment'][i]==1:
        p_b=unc_orfl
    else:
        p_b=1-unc_orfl
    if df3['On time Delivery'][i]==1:
        p_c=unc_ont
    else:
        p_c=1-unc_ont
    if df3['Transportation Quality'][i]==1:
        p_d=unc_trans
    else:
        p_d=1-unc_trans
    if df3['Delivery Performance'][i]==1:
        p_e=unc_dlp
    else:
        p_e=1-unc_dlp
    if df3['Consistency'][i]==1:
        p_f=unc_conc
    else:
        p_f=1-unc_conc
    nrp=nrp+df3['Network risk'][i]*p_a*p_b*p_c*p_d*p_e*p_f
    
    
erp=0
for i in range(len(df4)):
    if df4['Responsiveness'][i]==1:
        p_a= unc_resp
    else:
        p_a=1-unc_resp
    if df4['Co_operativeness'][i]==1:
        p_b=unc_Co
    else:
        p_b=1-unc_Co
    if df4['Flexibility'][i]==1:
        p_c=unc_flex
    else:
        p_c=1-unc_flex
    if df4['After sale service'][i]==1:
        p_d=unc_afss
    else:
        p_d=1-unc_afss

    erp=erp+df4['External risk'][i]*p_a*p_b*p_c*p_d
ovr_risk=(orp+nrp+erp)/3
result=rf.predict([[res,coop,trans,pack,con,ont,dlp,fin,leng,strn,flex,odf,afs,qnt,tp,ltd,unt,Quality,order_value,delivery,reliability,weighted_lead,ttl_p,orp,nrp,erp,ovr_risk]])
data=raw_data

# Calculate the average value based on EWO No
average_values = data.groupby('Vendor')['overall_risk'].mean()
performance=data.groupby('Vendor')['Total Performance'].mean()
risk=average_values[result]
per=performance[result]
sup=f"Selected supplier: {result}"
print(sup)
per=f"Overall performance of the supplier: {per}"
print(per)
ri=f"Risk factor: {risk}"
print(ri)
# Out:
# Enter the value of responsivenes[1~5]5
# Enter the value of Cooperativeness[1~5]5
# Enter the value of Transportation Quality[1~5]5
# Enter the value of packaging[1~5]5
# Enter the value of consistency[1~5]4
# Enter the value of on time delivery[0/1]1
# Enter the value of delivery performance[1~5]5
# Enter the value of Fineness[1~5]5
# Enter the value of yarn length in cm175
# Enter the value of yarn strength in gm/denier3.8
# Enter the value of Flexibility[1~5]4
# Enter the value of order fullfillment[0/1]1
# Enter the value of after sale service[1~5]4
# Enter the value of quantity40
# Enter the value of unit price2.8
# Enter the value of lead time[1~5]4
# Selected supplier: ['V85']
# Overall performance of the supplier: Vendor
# V85    74.589762
# Name: Total Performance, dtype: float64
# Risk factor: Vendor
# V85    0.17069
# Name: overall_risk, dtype: float64
# ...

# %%
result=rf.predict([[res,coop,trans,pack,con,ont,dlp,fin,leng,strn,flex,odf,afs,qnt,tp,ltd,unt,Quality,order_value,delivery,reliability,weighted_lead,ttl_p,orp,nrp,erp,ovr_risk]])
# Out:
# C:\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
data=raw_data

# Calculate the average value based on EWO No
average_values = data.groupby('Vendor')['overall_risk'].mean()
average_values[result]
# Out:
# Vendor
# V71    0.214325
# Name: overall_risk, dtype: float64

# %%
erp
# Out:
# 0.08000000000000002

# %%
ovr_risk
# Out:
# 0.12570219299657162
